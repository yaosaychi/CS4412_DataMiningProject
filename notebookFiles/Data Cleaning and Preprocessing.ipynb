# %% [markdown]
# # 1. Importing Frameworks and DataSet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\Yaw\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
online_retail = fetch_ucirepo(id=352)

# data (as pandas dataframes)
X = online_retail.data.features
y = online_retail.data.targets

# metadata
print(online_retail.metadata)

# variable information
print(online_retail.variables)
# Out:
# {'uci_id': 352, 'name': 'Online Retail', 'repository_url': 'https://archive.ics.uci.edu/dataset/352/online+retail', 'data_url': 'https://archive.ics.uci.edu/static/public/352/data.csv', 'abstract': 'This is a transactional data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.', 'area': 'Business', 'tasks': ['Classification', 'Clustering'], 'characteristics': ['Multivariate', 'Sequential', 'Time-Series'], 'num_instances': 541909, 'num_features': 6, 'feature_types': ['Integer', 'Real'], 'demographics': [], 'target_col': None, 'index_col': ['InvoiceNo', 'StockCode'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2015, 'last_updated': 'Mon Oct 21 2024', 'dataset_doi': '10.24432/C5BW33', 'creators': ['Daqing Chen'], 'intro_paper': {'ID': 361, 'type': 'NATIVE', 'title': 'Data mining for the online retail industry: A case study of RFM model-based customer segmen
# ...

# %% [markdown]
# # 2.  Inspecting the Raw Dataset.

# %%
df = online_retail.data.original #instantiating a dataframe containing the dataset.

# %%
print(df.head()) #viewing the first five rows of the dataset.
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print(df.info())
print(df.describe())
#these show the various datatypes of the attributes and relevant statistical descriptions.
#
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  540455 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB
# None
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# ...

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.isnull().sum()
#identifying the total number of rows containing an attribute that is null.
#this shows that there are 1454 rows that have a null description attribute.
# a similar issue can be raised for the customerID field.
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
# ...

# %% [markdown]
# # 3. Visualizing the Raw Data.

# %%
#summary of the quantity attribute.
# notes: this shows that there no missing quantity input as the count of quantity instances matches the total number of rows in the data.
df["Quantity"].describe()
# Out:
# count    541909.000000
# mean          9.552250
# std         218.081158
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
df["Quantity"].plot.hist(bins=10,color = 'steelblue').set_title("Distribution of Quantity")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["Quantity"].plot.hist(bins=10,color = 'steelblue').set_title("Distribution of Quantity")
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
ax = df.boxplot(column="Quantity")
ax.set_ylabel("Quantity Intervals")
ax.set_title("Quantity Boxplot")
plt.show()

# %%
#summary of the unit price attribute.
# notes: from the description presented it can be seen that there is a negative unit price. for a dataset which focuses on sales, negative values should be discarded as they do not account for actual sales.
df["UnitPrice"].describe()
# Out:
# count    541909.000000
# mean          4.611114
# std          96.759853
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
df["UnitPrice"].plot.hist(bins=10, color = 'steelblue')
plt.xlim(-8000,8000)
plt.show()



#notes: it can be seen that for the unit price some values lie to the left of the origin indicating that there are some refunds.

# %%
# Top 10 by number of rows (purchases)
top10 = df["StockCode"].value_counts().head(10)

ah = top10.plot(
    kind="barh",
    figsize=(8, 5),
    color="steelblue",
    edgecolor="black"
)

ah.invert_yaxis()           # highest at top
ah.set_xlabel("Number of purchases")
ah.set_ylabel("Product")
ah.set_title("Top 10 Most Purchased Products")

plt.tight_layout()
plt.show()

# %%
# rows with a valid customerID
cust_transaction = df.dropna(subset=['CustomerID'])

# One transaction = one unique invoice for that customer
transaction_per_cust = (cust_transaction[['CustomerID', 'InvoiceNo']]
               .drop_duplicates()
               .groupby('CustomerID')['InvoiceNo']
               .count()
               .rename('num_invoices'))

#chekcing the customer transactions.
transaction_per_cust.head()
# Out:
# CustomerID
# 12346.0    2
# 12347.0    7
# 12348.0    4
# 12349.0    1
# 12350.0    1
# Name: num_invoices, dtype: int64

# %%
#plotting the distribution of invoices per customer.
plt.figure(figsize=(8,4))
sns.histplot(transaction_per_cust, bins=50, kde=False, color='steelblue')
plt.xlabel('Number of invoices per customer')
plt.ylabel('Number of customers')
plt.title('Distribution of Transactions per Customer')

plt.xlim(0,40) #limiting the range of the x-axis to at most 40 invoices.
plt.tight_layout()
plt.show()

# %%
#since invoice date and time is stored as a string, first convert that to the datatime datatype.
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceMonth'] = df['InvoiceDate'].dt.to_period('M')
transaction_per_month = (df[['InvoiceMonth', 'InvoiceNo']].groupby(
    'InvoiceMonth')['InvoiceNo'].count())

transaction_per_month.index = transaction_per_month.index.to_timestamp()

#plotting the monthly transaction counts
plt.figure(figsize=(10,6))
sns.lineplot(x=transaction_per_month.index, y=transaction_per_month.values, marker='o', color = 'steelblue')
plt.xlabel('Month')
plt.ylabel('Number of invoices')
plt.title('Monthly Transactions Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Data Preprocessing and Cleaning

# %%
#removing cancellations from the data frame.
df = df[~df['InvoiceNo'].astype(str).str.startswith('C')]

# %%
df.shape
# Out:
# (532621, 9)

# %%
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 532621 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     532621 non-null  str
#  1   StockCode     532621 non-null  str
#  2   Description   531167 non-null  str
#  3   Quantity      532621 non-null  int64
#  4   InvoiceDate   532621 non-null  datetime64[us]
#  5   UnitPrice     532621 non-null  float64
#  6   CustomerID    397924 non-null  float64
#  7   Country       532621 non-null  str
#  8   InvoiceMonth  532621 non-null  period[M]
# dtypes: datetime64[us](1), float64(2), int64(1), period[M](1), str(4)
# memory usage: 40.6 MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoiceMonth
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom      2010-12
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      2010-12
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom      2010-12
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      2010-12
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      2010-12

# %%
#checking for the presence of data from countries aside from the United Kingdom.
df['Country'].unique()
# Out:
# <StringArray>
# [      'United Kingdom',               'France',            'Australia',
#           'Netherlands',              'Germany',               'Norway',
#                  'EIRE',          'Switzerland',                'Spain',
#                'Poland',             'Portugal',                'Italy',
#               'Belgium',            'Lithuania',                'Japan',
#               'Iceland',      'Channel Islands',              'Denmark',
#                'Cyprus',               'Sweden',              'Finland',
#               'Austria',              'Bahrain',               'Israel',
#                'Greece',            'Hong Kong',            'Singapore',
#               'Lebanon', 'United Arab Emirates',         'Saudi Arabia',
#        'Czech Republic',               'Canada',          'Unspecified',
#                'Brazil',                  'USA',   'European Community',
#                 'Malta',                  'RSA']
# Length: 38, dtype: str

# %%
#removing all rows which contain data from other countries.
df = df[df['Country'] == 'United Kingdom']
df.tail()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country InvoiceMonth
# 541889 2011-12-09 12:31:00       1.95     15804.0  United Kingdom      2011-12
# 541890 2011-12-09 12:49:00       2.95     13113.0  United Kingdom      2011-12
# 541891 2011-12-09 12:49:00       1.25     13113.0  United Kingdom      2011-12
# 541892 2011-12-09 12:49:00       8.95     13113.0  United Kingdom      2011-12
# 541893 2011-12-09 12:49:00       7.08     13113.0  United Kingdom      2011-12

# %%
#removing all quantities less than zero. Ensuring there are only fulfilled orders.

df= df[df['Quantity'] > 0]

# %%
df['Quantity'].unique()
# Out:
# array([    6,     8,     2,    32,     3,     4,    80,    48,    64,
#           10,    12,   120,    24,    96,    23,     5,     1,    36,
#           50,    40,   100,   192,   432,   144,   288,    16,    20,
#            9,   128,    25,    30,    28,     7,    56,    72,   200,
#          600,   480,    14,    18,    11,    33,    13,    70,   252,
#           60,   216,   384,    27,    15,    22,    19,    17,    21,
#           34,    47,   108,    52,    75,   270,    42,   240,    90,
#          320,  1824,   204,    69,   160,  2880,  1400,    39,    26,
#           31,    82,    78,    97,    98,    35,    57,   110,   720,
#          156,   324,    38,    37,    49,    95,    29,    41,   402,
#          378,   150,   300,    54,   104,    67,   258,    66,    44,
#           55,    46,    99,    61,   408,   972,   208,  1008,  1000,
#          250,  1394,   400,    79,    84,   272,   113,    45,   106,
# ...

# %%
df.shape
# Out:
# (486286, 9)

# %%
#removing any entry with a missing description field.

#checking for the presence of null descriptions.
df_null_desc = df[df['Description'].isna() | (df['Description'].isnull()) | (df['Description'] == '')]

# %%
df_null_desc.count()
# Out:
# InvoiceNo       592
# StockCode       592
# Description       0
# Quantity        592
# InvoiceDate     592
# UnitPrice       592
# CustomerID        0
# Country         592
# InvoiceMonth    592
# dtype: int64

# %%
df_null_desc
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2010-12-01 11:52:00
# 1970      536545     21134         NaN         1 2010-12-01 14:32:00
# 1971      536546     22145         NaN         1 2010-12-01 14:33:00
# 1972      536547     37509         NaN         1 2010-12-01 14:33:00
# 1987      536549    85226A         NaN         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 533712    581103     22689         NaN         4 2011-12-07 11:58:00
# 535326    581203     23406         NaN        15 2011-12-07 18:31:00
# 535332    581209     21620         NaN         6 2011-12-07 18:35:00
# 536981    581234     72817         NaN        27 2011-12-08 10:33:00
# 538554    581408     85175         NaN        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country InvoiceMonth
# 622           0.0         NaN  United Kingdom      2010-12
# ...

# %%
# rows with null Description and very large quantity
suspect_null_desc = df_null_desc[df_null_desc['Quantity'] > 56]
suspect_null_desc
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 7187      536995     35951         NaN        57 2010-12-03 15:29:00
# 7191      536999     21421         NaN       110 2010-12-03 15:32:00
# 7194      537002     21651         NaN        70 2010-12-03 15:33:00
# 13263     537430     85215         NaN       120 2010-12-06 16:05:00
# 20037     538004     22114         NaN       144 2010-12-09 12:11:00
# ...          ...       ...         ...       ...                 ...
# 404391    571674     23702         NaN       100 2011-10-18 13:22:00
# 440210    574518     21174         NaN        63 2011-11-04 13:42:00
# 453998    575505      POST         NaN       800 2011-11-10 10:29:00
# 453999    575506        C2         NaN       150 2011-11-10 10:30:00
# 468528    576509     21868         NaN       144 2011-11-15 12:03:00
#
#         UnitPrice  CustomerID         Country InvoiceMonth
# 7187          0.0         NaN  United Kingdom      2010-12
# ...

# %%
suspect_null_desc.sort_values('Quantity', ascending=False).head(20)
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 74614     542504     37413         NaN      5568 2011-01-28 12:03:00
# 74615     542505    79063D         NaN      2560 2011-01-28 12:04:00
# 82795     543258    84611B         NaN      1287 2011-02-04 16:06:00
# 52262     540699      POST         NaN      1000 2011-01-11 09:32:00
# 136537    547966       DOT         NaN      1000 2011-03-28 15:49:00
# 80665     543051    79062D         NaN       960 2011-02-03 10:15:00
# 205991    554857      POST         NaN       800 2011-05-27 10:08:00
# 453998    575505      POST         NaN       800 2011-11-10 10:29:00
# 326552    565556      POST         NaN       750 2011-09-05 12:14:00
# 336309    566316     23306         NaN       682 2011-09-12 10:07:00
# 30364     538861     22444         NaN       460 2010-12-14 14:04:00
# 297437    562945     79000         NaN       425 2011-08-11 09:35:00
# 381842    569895     23348         NaN       420 2011-10-06 15:55:00
# ...

# %%
suspect_null_desc.sort_values('UnitPrice', ascending=False).head(20)
# Out:
#       InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 7187     536995     35951         NaN        57 2010-12-03 15:29:00
# 7191     536999     21421         NaN       110 2010-12-03 15:32:00
# 7194     537002     21651         NaN        70 2010-12-03 15:33:00
# 13263    537430     85215         NaN       120 2010-12-06 16:05:00
# 20037    538004     22114         NaN       144 2010-12-09 12:11:00
# 21778    538129     84497         NaN        79 2010-12-09 15:55:00
# 21780    538131    17091A         NaN        84 2010-12-09 15:56:00
# 22295    538160     20956         NaN       288 2010-12-09 17:18:00
# 30364    538861     22444         NaN       460 2010-12-14 14:04:00
# 52262    540699      POST         NaN      1000 2011-01-11 09:32:00
# 73752    542378    84279B         NaN       192 2011-01-27 13:56:00
# 73934    542394     84452         NaN        65 2011-01-27 15:11:00
# 74614    542504     37413         NaN      5568 2011-01-28 12:03:00
# ...

# %%
#with the unit price in mind it will be okay to remove all items without descriptions.
# count before
before = df.shape[0]

# drop null, NaN, and empty-string descriptions
df = df[~(df['Description'].isna() | (df['Description'].str.strip() == ''))]

# count after and how many dropped
after = df.shape[0]
dropped = before - after
print("Dropped rows with null/NaN/empty Description:", dropped)
# Out:
# Dropped rows with null/NaN/empty Description: 592

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoiceMonth
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom      2010-12
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      2010-12
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom      2010-12
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      2010-12
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      2010-12

# %%
df.shape
# Out:
# (485694, 9)

# %%
# rows with UnitPrice equal to 0
zero_price = df[df['UnitPrice'] == 0]

# rows with UnitPrice less than 0
neg_price = df[df['UnitPrice'] < 0]

# rows with UnitPrice zero OR less than zero
zero_or_neg = df[df['UnitPrice'] <= 0]

zero_or_neg
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 6391      536941     22734                            amazon        20
# 6392      536942     22139                            amazon        15
# 14335     537534     85064      CREAM SWEETHEART LETTER RACK         1
# 14336     537534     84832  ZINC WILLIE WINKIE  CANDLE STICK         1
# 14337     537534     84692       BOX OF 24 COCKTAIL PARASOLS         2
# ...          ...       ...                               ...       ...
# 524622    580609     22927                            Amazon         1
# 535325    581202     23404                             check        41
# 535334    581211     22142                             check        14
# 538504    581406    46000M      POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S      POLYESTER FILLER PAD 40x40cm       300
#
#                InvoiceDate  UnitPrice  CustomerID         Country InvoiceMonth
# ...

# %%
#dropping all rows with a unit price at 0 or less than zero since the store cannot sell items with a zero pound sterling unit price.

# number of rows before
before = df.shape[0]

# keep only rows with positive UnitPrice
df = df[df['UnitPrice'] > 0]

# number of rows removed
after = df.shape[0]
dropped = before - after
print("Dropped rows with UnitPrice <= 0:", dropped)
# Out:
# Dropped rows with UnitPrice <= 0: 571

# %%
#creating a total price column for the table.
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
#checking the item with the highest quantity bought after georestriction and null cleanup.
df_sortedByQuantity = df.sort_values('Quantity', ascending=False)
df_sortedByQuantity.head()
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 540421    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 421632    573008     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197               SMALL POPCORN HOLDER      4300
# 97432     544612     22053              EMPIRE DESIGN ROSETTE      3906
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom
# 61619  2011-01-18 10:01:00       1.04     12346.0  United Kingdom
# 421632 2011-10-27 12:26:00       0.21     12901.0  United Kingdom
# 206121 2011-05-27 10:52:00       0.72     13135.0  United Kingdom
# 97432  2011-02-22 10:43:00       0.82     18087.0  United Kingdom
#
#        InvoiceMonth  TotalPrice
# 540421      2011-12   168469.60
# 61619       2011-01    77183.60
# 421632      2011-10     1008.00
# ...

# %% [markdown]
# # 5. Data Transformation for Apriori Algorithm and Association Rules
# **Threshold justification:**
# - `min_support = 0.01` (1% of invoices). At 0.02 only 5 rules survived. At 0.01, 177 rules emerged across three distinct product families. At 0.005, >2,000 rules with many trivial patterns.
# - `min_confidence = 0.80`: Each rule predicts its consequent in at least 80% of qualifying transactions.

# %%
# grouping by invoiceNo
baskets = (
    df.groupby("InvoiceNo")["Description"]
      .apply(list)
      .reset_index(name="items")
)

#transactions converted into a list of lists.
transactions = baskets["items"].tolist()

from mlxtend.preprocessing  import TransactionEncoder
transEncoder = TransactionEncoder()
transEncoderArray = transEncoder.fit(transactions).transform(transactions)

basketMatrix = pd.DataFrame(transEncoderArray, columns=transEncoder.columns_)

print(f'Transaction matrix: {basketMatrix.shape[0]:,} invoices x {basketMatrix.shape[1]:,} unique products')
# Out:
# Transaction matrix: 18,019 invoices x 4,007 unique products

# %%
## running apriori algorithm on the basketMatrix. With minSupport of 0.01

from mlxtend.frequent_patterns import apriori, association_rules

frequent_itemsets = apriori(basketMatrix, min_support= 0.01 ,use_colnames=True)

# %%
#displaying the last five items in the frequent itemset list.
frequent_itemsets.tail()
# Out:
#        support                                           itemsets
# 2151  0.010544  frozenset({LUNCH BAG SPACEBOY DESIGN , LUNCH B...
# 2152  0.011044  frozenset({LUNCH BAG PINK POLKADOT, LUNCH BAG ...
# 2153  0.010267  frozenset({LUNCH BAG SPACEBOY DESIGN , LUNCH B...
# 2154  0.010045  frozenset({LUNCH BAG SPACEBOY DESIGN , LUNCH B...
# 2155  0.010933  frozenset({CHARLOTTE BAG PINK POLKADOT, WOODLA...

# %%
#displaying the frist few items in the frequent itemset list.
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
frequent_itemsets.head()
# Out:
#     support                                          itemsets
# 0  0.014041     frozenset({ SET 2 TEA TOWELS I LOVE LONDON })
# 1  0.015151               frozenset({10 COLOUR SPACEBOY PEN})
# 2  0.013375      frozenset({12 MESSAGE CARDS WITH ENVELOPES})
# 3  0.018148        frozenset({12 PENCIL SMALL TUBE WOODLAND})
# 4  0.018813  frozenset({12 PENCILS SMALL TUBE RED RETROSPOT})

# %%
item_rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.8)
print(f'Association rules (conf >= 0.80): {len(item_rules)}')
item_rules.sort_values('lift',ascending=False)
# Out:
# Association rules (conf >= 0.80): 177
#                                            antecedents  \
# 117  frozenset({HERB MARKER ROSEMARY, HERB MARKER P...
# 118                     frozenset({HERB MARKER THYME})
# 110   frozenset({HERB MARKER THYME, HERB MARKER MINT})
# 113                  frozenset({HERB MARKER ROSEMARY})
# 108                   frozenset({HERB MARKER PARSLEY})
# ..                                                 ...
# 52   frozenset({JUMBO BAG PINK POLKADOT, DOTCOM POS...
# 53   frozenset({JUMBO BAG PINK VINTAGE PAISLEY, DOT...
# 125  frozenset({JUMBO BAG STRAWBERRY, JUMBO BAG PIN...
# 129  frozenset({JUMBO STORAGE BAG SUKI, JUMBO BAG P...
# 51   frozenset({JUMBO  BAG BAROQUE BLACK WHITE, DOT...
#
#                                            consequents  antecedent support  \
# 117                     frozenset({HERB MARKER THYME})            0.011488
# 118  frozenset({HERB MARKER ROSEMARY, HERB MARKER P...            0.012764
# ...

# %%
## disproving the use of the support value of 0.02.
#apriori at min_sup = 0.02
frequent_itemsets2 = apriori(basketMatrix, min_support= 0.02 ,use_colnames=True)

# %%
item_rules2 = association_rules(frequent_itemsets2, metric='confidence', min_threshold= 0.8)

# %%
item_rules2
# Out:
#                                          antecedents  \
# 0        frozenset({PINK REGENCY TEACUP AND SAUCER})
# 1  frozenset({GREEN REGENCY TEACUP AND SAUCER, PI...
# 2  frozenset({PINK REGENCY TEACUP AND SAUCER, ROS...
# 3  frozenset({JUMBO SHOPPER VINTAGE RED PAISLEY, ...
# 4  frozenset({JUMBO STORAGE BAG SUKI, JUMBO BAG P...
#
#                                      consequents  antecedent support  \
# 0   frozenset({GREEN REGENCY TEACUP AND SAUCER})            0.038959
# 1  frozenset({ROSES REGENCY TEACUP AND SAUCER })            0.031966
# 2   frozenset({GREEN REGENCY TEACUP AND SAUCER})            0.030246
# 3           frozenset({JUMBO BAG RED RETROSPOT})            0.025196
# 4           frozenset({JUMBO BAG RED RETROSPOT})            0.028026
#
#    consequent support   support  confidence       lift  representativity  \
# 0            0.051723  0.031966    0.820513  15.863541               1.0
# 1            0.053055  0.027305    0.854167  16.099612               1.0
# ...

# %%
item_rules2.sort_values('lift', ascending=False )
# Out:
#                                          antecedents  \
# 2  frozenset({PINK REGENCY TEACUP AND SAUCER, ROS...
# 1  frozenset({GREEN REGENCY TEACUP AND SAUCER, PI...
# 0        frozenset({PINK REGENCY TEACUP AND SAUCER})
# 3  frozenset({JUMBO SHOPPER VINTAGE RED PAISLEY, ...
# 4  frozenset({JUMBO STORAGE BAG SUKI, JUMBO BAG P...
#
#                                      consequents  antecedent support  \
# 2   frozenset({GREEN REGENCY TEACUP AND SAUCER})            0.030246
# 1  frozenset({ROSES REGENCY TEACUP AND SAUCER })            0.031966
# 0   frozenset({GREEN REGENCY TEACUP AND SAUCER})            0.038959
# 3           frozenset({JUMBO BAG RED RETROSPOT})            0.025196
# 4           frozenset({JUMBO BAG RED RETROSPOT})            0.028026
#
#    consequent support   support  confidence       lift  representativity  \
# 2            0.051723  0.027305    0.902752  17.453534               1.0
# 1            0.053055  0.027305    0.854167  16.099612               1.0
# ...

# %%
item_rules2.sort_values('support', ascending = False )
# Out:
#                                          antecedents  \
# 0        frozenset({PINK REGENCY TEACUP AND SAUCER})
# 1  frozenset({GREEN REGENCY TEACUP AND SAUCER, PI...
# 2  frozenset({PINK REGENCY TEACUP AND SAUCER, ROS...
# 4  frozenset({JUMBO STORAGE BAG SUKI, JUMBO BAG P...
# 3  frozenset({JUMBO SHOPPER VINTAGE RED PAISLEY, ...
#
#                                      consequents  antecedent support  \
# 0   frozenset({GREEN REGENCY TEACUP AND SAUCER})            0.038959
# 1  frozenset({ROSES REGENCY TEACUP AND SAUCER })            0.031966
# 2   frozenset({GREEN REGENCY TEACUP AND SAUCER})            0.030246
# 4           frozenset({JUMBO BAG RED RETROSPOT})            0.028026
# 3           frozenset({JUMBO BAG RED RETROSPOT})            0.025196
#
#    consequent support   support  confidence       lift  representativity  \
# 0            0.051723  0.031966    0.820513  15.863541               1.0
# 1            0.053055  0.027305    0.854167  16.099612               1.0
# ...

# %%
def has_keyword(itemset, keyword):
    return any(keyword.upper() in str(i).upper() for i in itemset)

herb_rules   = item_rules[item_rules['antecedents'].apply(lambda x: has_keyword(x, 'HERB'))]
teacup_rules = item_rules[item_rules['antecedents'].apply(
    lambda x: has_keyword(x,'REGENCY') or has_keyword(x,'TEACUP'))]
jumbo_rules  = item_rules[item_rules['antecedents'].apply(lambda x: has_keyword(x, 'JUMBO'))]
other_rules  = item_rules.drop(
    index=herb_rules.index.union(teacup_rules.index).union(jumbo_rules.index))

print('Rule breakdown by product family:')
print(f'  Herb Marker family:    {len(herb_rules)}')
print(f'  Regency Teacup family: {len(teacup_rules)}')
print(f'  Jumbo Bag family:      {len(jumbo_rules)}')
print(f'  Other:                 {len(other_rules)}')
print(f'  Total:                 {len(item_rules)}')
# Out:
# Rule breakdown by product family:
#   Herb Marker family:    81
#   Regency Teacup family: 20
#   Jumbo Bag family:      38
#   Other:                 40
#   Total:                 177

# %%
plt.figure(figsize=(9, 5))
sc = plt.scatter(item_rules['support'], item_rules['lift'],
                 c=item_rules['confidence'], cmap='Blues',
                 alpha=0.75, edgecolors='grey', linewidths=0.3, s=60)
plt.colorbar(sc, label='Confidence')
plt.xlabel('Support')
plt.ylabel('Lift')
plt.title(f'Association Rules - Support vs. Lift (n={len(item_rules)}, conf >= 0.80)')
plt.tight_layout()
plt.show()

# %%
# effect of threshold choice
frequent_itemsets2 = apriori(basketMatrix, min_support=0.02, use_colnames=True)
item_rules2 = association_rules(frequent_itemsets2, metric='confidence', min_threshold=0.80)
print(f'At min_support=0.02: {len(item_rules2)} rules')
print(f'At min_support=0.01: {len(item_rules)} rules')
print('\nAll rules at min_support=0.02:')
item_rules2.sort_values('lift', ascending=False)[
    ['antecedents','consequents','support','confidence','lift']
]
# Out:
# At min_support=0.02: 5 rules
# At min_support=0.01: 177 rules
#
# All rules at min_support=0.02:
#                                          antecedents  \
# 2  frozenset({PINK REGENCY TEACUP AND SAUCER, ROS...
# 1  frozenset({GREEN REGENCY TEACUP AND SAUCER, PI...
# 0        frozenset({PINK REGENCY TEACUP AND SAUCER})
# 3  frozenset({JUMBO SHOPPER VINTAGE RED PAISLEY, ...
# 4  frozenset({JUMBO STORAGE BAG SUKI, JUMBO BAG P...
#
#                                      consequents   support  confidence  \
# 2   frozenset({GREEN REGENCY TEACUP AND SAUCER})  0.027305    0.902752
# 1  frozenset({ROSES REGENCY TEACUP AND SAUCER })  0.027305    0.854167
# 0   frozenset({GREEN REGENCY TEACUP AND SAUCER})  0.031966    0.820513
# 3           frozenset({JUMBO BAG RED RETROSPOT})  0.020312    0.806167
# 4           frozenset({JUMBO BAG RED RETROSPOT})  0.022476    0.801980
#
#         lift
# 2  17.453534
# 1  16.099612
# 0  15.863541
# 3   7.507147
# 4   7.468156

# %% [markdown]
# # 6. RFM Feature Engineering
#
# RFM reduces each customer to three interpretable behavioral dimensions:
# - **Recency** — days since last purchase (lower = more recent)
# - **Frequency** — number of distinct invoices
# - **Monetary** — total spend in GBP

# %%
reference_date = df['InvoiceDate'].max() + pd.Timedelta(days=1)
print(f'Reference date (day after last transaction): {reference_date.date()}')

df_cust = df.dropna(subset=['CustomerID']).copy()
df_cust['CustomerID'] = df_cust['CustomerID'].astype(int)

rfm = df_cust.groupby('CustomerID').agg(
    Recency  = ('InvoiceDate', lambda x: (reference_date - x.max()).days),
    Frequency= ('InvoiceNo',   'nunique'),
    Monetary = ('TotalPrice',  'sum')
).reset_index()

print(f'Customers with complete RFM: {len(rfm):,}')
rfm.describe().round(2)
# Out:
# Reference date (day after last transaction): 2011-12-10
# Customers with complete RFM: 3,920
#        CustomerID  Recency  Frequency   Monetary
# count     3920.00  3920.00    3920.00    3920.00
# mean     15562.06    92.21       4.25    1864.39
# std       1576.59    99.53       7.20    7482.82
# min      12346.00     1.00       1.00       3.75
# 25%      14208.75    18.00       1.00     300.28
# 50%      15569.50    51.00       2.00     652.28
# 75%      16913.25   143.00       5.00    1576.58
# max      18287.00   374.00     209.00  259657.30

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, col, color in zip(axes,
    ['Recency','Frequency','Monetary'],
    ['steelblue','darkorange','seagreen']):
    rfm[col].clip(upper=rfm[col].quantile(0.99)).hist(bins=40, color=color, ax=ax)
    ax.set_title(f'Distribution of {col} (99th pct clip)')
    ax.set_xlabel(col)
plt.suptitle('RFM Feature Distributions', y=1.02)
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm[['Recency','Frequency','Monetary']])
print('StandardScaler applied — mean ~0, std ~1 per feature')
pd.DataFrame(rfm_scaled, columns=['R_scaled','F_scaled','M_scaled']).describe().round(3)
# Out:
# StandardScaler applied — mean ~0, std ~1 per feature
#        R_scaled  F_scaled  M_scaled
# count  3920.000  3920.000  3920.000
# mean     -0.000     0.000     0.000
# std       1.000     1.000     1.000
# min      -0.916    -0.451    -0.249
# 25%      -0.746    -0.451    -0.209
# 50%      -0.414    -0.312    -0.162
# 75%       0.510     0.105    -0.038
# max       2.831    28.445    34.456

# %% [markdown]
# # 7. K-Means Clustering
#
# K is selected using the elbow method (inertia) and silhouette coefficient.

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

inertias    = []
silhouettes = []
K_range     = range(2, 9)

for k in K_range:
    km  = KMeans(n_clusters=k, random_state=42, n_init=10)
    lbl = km.fit_predict(rfm_scaled)
    inertias.append(km.inertia_)
    silhouettes.append(silhouette_score(rfm_scaled, lbl))

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(list(K_range), inertias, 'o-', color='steelblue')
axes[0].axvline(x=4, linestyle='--', color='red', alpha=0.5, label='k=4 selected')
axes[0].set_xlabel('k'); axes[0].set_ylabel('Inertia')
axes[0].set_title('Elbow Method'); axes[0].legend()

axes[1].plot(list(K_range), silhouettes, 'o-', color='darkorange')
axes[1].axvline(x=4, linestyle='--', color='red', alpha=0.5, label='k=4 selected')
axes[1].set_xlabel('k'); axes[1].set_ylabel('Silhouette Score')
axes[1].set_title('Silhouette Score by k'); axes[1].legend()

plt.tight_layout()
plt.show()

best_k = list(K_range)[silhouettes.index(max(silhouettes))]
print(f'Best k by silhouette: {best_k} (score={max(silhouettes):.3f})')
print('k=4 selected: elbow inflection point + interpretable four-segment business model')
# Out:
# Best k by silhouette: 2 (score=0.886)
# k=4 selected: elbow inflection point + interpretable four-segment business model

# %%
km_final = KMeans(n_clusters=4, random_state=42, n_init=10)
rfm['KMeans_Cluster'] = km_final.fit_predict(rfm_scaled)

cluster_profile = rfm.groupby('KMeans_Cluster').agg(
    Count         = ('CustomerID','count'),
    Avg_Recency   = ('Recency',   'mean'),
    Avg_Frequency = ('Frequency', 'mean'),
    Avg_Monetary  = ('Monetary',  'mean'),
    Total_Revenue = ('Monetary',  'sum')
).round(1)

cluster_profile['Revenue_Share_%'] = (
    cluster_profile['Total_Revenue'] /
    cluster_profile['Total_Revenue'].sum() * 100).round(1)

sil_final = silhouette_score(rfm_scaled, rfm['KMeans_Cluster'])
print(f'Silhouette score (k=4): {sil_final:.3f}')
cluster_profile
# Out:
# Silhouette score (k=4): 0.595
#                 Count  Avg_Recency  Avg_Frequency  Avg_Monetary  \
# KMeans_Cluster
# 0                 989        244.6            1.6         526.7
# 1                  52         12.2           43.8       31172.2
# 2                2876         41.4            4.4        1579.9
# 3                   3          3.3           36.0      207560.2
#
#                 Total_Revenue  Revenue_Share_%
# KMeans_Cluster
# 0                    520941.3              7.1
# 1                   1620955.4             22.2
# 2                   4543814.4             62.2
# 3                    622680.6              8.5

# %%
# Assign business labels based on RFM centroid values
profile = rfm.groupby('KMeans_Cluster').agg(
    R=('Recency', 'mean'), F=('Frequency', 'mean'), M=('Monetary', 'mean'))

names = {profile['M'].idxmax(): 'Champions'}
remaining = [c for c in profile.index if c not in names]
names[profile.loc[remaining, 'F'].idxmax()] = 'Loyal Regulars'
remaining = [c for c in profile.index if c not in names]
names[profile.loc[remaining, 'R'].idxmax()] = 'At-Risk / Lapsed'
remaining = [c for c in profile.index if c not in names]
names[remaining[0]] = 'New / Occasional'

rfm['Segment'] = rfm['KMeans_Cluster'].map(names)
print('Segment sizes:')
print(rfm['Segment'].value_counts())
# Out:
# Segment sizes:
# Segment
# New / Occasional    2876
# At-Risk / Lapsed     989
# Loyal Regulars        52
# Champions              3
# Name: count, dtype: int64

# %% [markdown]
# # 8. DBSCAN Clustering (Comparison)
#
# DBSCAN is run on the same standardised RFM features to compare cluster structures and cross-validate anomaly flags.

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.5, min_samples=5)
rfm['DBSCAN_Cluster'] = dbscan.fit_predict(rfm_scaled)

n_db_clusters = len(set(rfm['DBSCAN_Cluster'])) - (1 if -1 in rfm['DBSCAN_Cluster'].values else 0)
n_noise       = (rfm['DBSCAN_Cluster'] == -1).sum()

print(f'DBSCAN clusters (excl. noise): {n_db_clusters}')
print(f'Noise points:                  {n_noise} ({n_noise/len(rfm)*100:.1f}%)')
print('\nCluster size distribution:')
print(rfm['DBSCAN_Cluster'].value_counts().sort_index())
# Out:
# DBSCAN clusters (excl. noise): 2
# Noise points:                  52 (1.3%)
#
# Cluster size distribution:
# DBSCAN_Cluster
# -1      52
#  0    3863
#  1       5
# Name: count, dtype: int64

# %%
noise_mask = rfm['DBSCAN_Cluster'] == -1
print('DBSCAN noise points by K-Means segment:')
print(rfm.loc[noise_mask,'Segment'].value_counts())
print('\nConclusion: DBSCAN noise aligns strongly with Champions and high-value outliers, consistent with LOF findings.')
# Out:
# DBSCAN noise points by K-Means segment:
# Segment
# Loyal Regulars      37
# New / Occasional     7
# At-Risk / Lapsed     5
# Champions            3
# Name: count, dtype: int64
#
# Conclusion: DBSCAN noise aligns strongly with Champions and high-value outliers, consistent with LOF findings.

# %% [markdown]
# # 9. PCA Visualization
#
# PCA reduces the 3D RFM space to 2 principal components for plotting. Explained variance confirms information preservation.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=42)
pca_coords = pca.fit_transform(rfm_scaled)

print(f'PC1 explained variance: {pca.explained_variance_ratio_[0]*100:.1f}%')
print(f'PC2 explained variance: {pca.explained_variance_ratio_[1]*100:.1f}%')
print(f'Total (2 components):   {pca.explained_variance_ratio_.sum()*100:.1f}%')

loadings = pd.DataFrame(pca.components_.T, columns=['PC1','PC2'],
                         index=['Recency','Frequency','Monetary'])
print('\nPCA component loadings:')
print(loadings.round(3))
# Out:
# PC1 explained variance: 54.6%
# PC2 explained variance: 29.8%
# Total (2 components):   84.4%
#
# PCA component loadings:
#              PC1    PC2
# Recency   -0.413  0.884
# Frequency  0.670  0.131
# Monetary   0.618  0.448

# %%
pca_df = pd.DataFrame(pca_coords, columns=['PC1','PC2'])
pca_df['Segment']      = rfm['Segment'].values
pca_df['DBSCAN_noise'] = (rfm['DBSCAN_Cluster'] == -1).values

palette = {
    'Champions':       '#e6194b',
    'Loyal Regulars':  '#3cb44b',
    'At-Risk / Lapsed':'#4363d8',
    'New / Occasional':'#f58231'
}

fig, ax = plt.subplots(figsize=(10, 7))
for seg, color in palette.items():
    m = pca_df['Segment'] == seg
    ax.scatter(pca_df.loc[m,'PC1'], pca_df.loc[m,'PC2'],
               label=seg, color=color, alpha=0.5, s=20)

# Overlay DBSCAN noise
m_noise = pca_df['DBSCAN_noise']
ax.scatter(pca_df.loc[m_noise,'PC1'], pca_df.loc[m_noise,'PC2'],
           marker='x', color='black', s=50, linewidths=1.5,
           label='DBSCAN noise', zorder=5)

ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% variance)')
ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% variance)')
ax.set_title('Customer Segments in PCA Space (RFM Features)')
ax.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10. Anomaly Detection — Local Outlier Factor (LOF)
#
# LOF identifies customers whose purchasing behavior is locally anomalous relative to their nearest neighbors in RFM space. contamination=0.05 flags the 5% most anomalous.

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(n_neighbors=20, contamination=0.05)
lof_labels = lof.fit_predict(rfm_scaled)
rfm['LOF_label'] = lof_labels
rfm['LOF_score'] = -lof.negative_outlier_factor_

n_outliers = (lof_labels == -1).sum()
print(f'LOF anomalies: {n_outliers} ({n_outliers/len(rfm)*100:.1f}% of customers)')
# Out:
# LOF anomalies: 196 (5.0% of customers)

# %%
anomalies = rfm[rfm['LOF_label']==-1].sort_values('LOF_score', ascending=False)

print('=== Top 10 most anomalous customers ===')
print(anomalies[['CustomerID','Recency','Frequency','Monetary','LOF_score','Segment']]
      .head(10).to_string(index=False))

print('\n=== Anomaly count by segment ===')
print(rfm.groupby('Segment')['LOF_label'].apply(lambda x: (x==-1).sum()))
# Out:
# === Top 10 most anomalous customers ===
#  CustomerID  Recency  Frequency  Monetary  LOF_score          Segment
#       16754      372          1   2002.40   6.433458 At-Risk / Lapsed
#       12748        1        209  33719.73   6.102733   Loyal Regulars
#       16048      373          2    256.44   5.293406 At-Risk / Lapsed
#       18102        1         60 259657.30   4.969851        Champions
#       14813      370          2    155.43   4.292114 At-Risk / Lapsed
#       17850      372         34   5391.21   4.034240 At-Risk / Lapsed
#       12967      358          2   1660.90   3.967778 At-Risk / Lapsed
#       16446        1          2 168472.50   3.852541        Champions
#       17450        8         46 194550.79   3.579474        Champions
#       15098      182          3  39916.50   3.490667 At-Risk / Lapsed
#
# === Anomaly count by segment ===
# Segment
# At-Risk / Lapsed    85
# Champions            3
# Loyal Regulars      23
# New / Occasional    85
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sc = axes[0].scatter(pca_coords[:,0], pca_coords[:,1],
                     c=rfm['LOF_score'], cmap='YlOrRd', alpha=0.6, s=15)
plt.colorbar(sc, ax=axes[0], label='LOF Score (higher = more anomalous)')
axes[0].set_xlabel('PC1'); axes[0].set_ylabel('PC2')
axes[0].set_title('LOF Anomaly Scores in PCA Space')

rfm['Monetary_log'] = np.log1p(rfm['Monetary'])
rfm['Status'] = rfm['LOF_label'].map({1:'Normal', -1:'Anomaly'})
rfm.boxplot(column='Monetary_log', by='Status', ax=axes[1],
            boxprops=dict(color='steelblue'),
            medianprops=dict(color='red', linewidth=2))
axes[1].set_title('Monetary Value (log) — Anomalies vs Normal')
axes[1].set_xlabel('Customer Status')
axes[1].set_ylabel('log(1 + Total Spend GBP)')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %%
# Investigate top anomalous customers — what did they buy?
top_ids = anomalies['CustomerID'].head(5).tolist()
print('Top transactions for most anomalous customers:')
(
    df_cust[df_cust['CustomerID'].isin(top_ids)]
    .sort_values('TotalPrice', ascending=False)
    [['CustomerID','InvoiceNo','InvoiceDate','Description','Quantity','UnitPrice','TotalPrice']]
    .head(15)
)
# Out:
# Top transactions for most anomalous customers:
#         CustomerID InvoiceNo         InvoiceDate  \
# 16438        18102    537659 2010-12-07 16:43:00
# 411231       18102    572209 2011-10-21 12:08:00
# 411230       18102    572209 2011-10-21 12:08:00
# 411229       18102    572209 2011-10-21 12:08:00
# 411232       18102    572209 2011-10-21 12:08:00
# 411235       18102    572209 2011-10-21 12:08:00
# 411234       18102    572209 2011-10-21 12:08:00
# 84319        18102    543378 2011-02-07 15:34:00
# 84323        18102    543379 2011-02-07 15:37:00
# 540061       18102    581457 2011-12-08 18:43:00
# 16440        18102    537659 2010-12-07 16:43:00
# 343083       18102    566931 2011-09-15 15:27:00
# 16429        18102    537657 2010-12-07 16:42:00
# 225606       18102    556725 2011-06-14 11:28:00
# 411233       18102    572209 2011-10-21 12:08:00
#
#                               Description  Quantity  UnitPrice  TotalPrice
# ...
